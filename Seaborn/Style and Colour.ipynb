# %% [markdown]
# ## **Style and Colour**
#
# ### **Method -** `set_style()`
#
# Set the parameters that control the general style of the plots.
#
# The style parameters control properties like the color of the background and
# whether a grid is enabled by default. This is accomplished using the
# matplotlib rcParams system.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()

sns.set_style('ticks')
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### **Spine Removal**
#
#
# `despine()` remove the top and right spines from plot(s).

# %%
sns.countplot(x='sex',data=tips)
sns.despine()

# %% [markdown]
# ### **Size and Aspect**
#
# To change the size of *most* seaborn plots use:
#
# `plot.figure(figsize=(width,height))`

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### **Method -** `set_context()`
#
# `set_context` allows you to override default parameters
#
# The base context is "notebook", and the other contexts are "paper", "talk",
# and "poster", which are version of the notebook parameters scaled by different
# values.
#
# Font elements can also be scaled independently of (but relative to)
# the other values.

# %%
sns.set_context('notebook')
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### **Colormap**
#
# If you would like to explore the strings to set a certain palette refer to:
#
# https://matplotlib.org/stable/gallery/color/colormap_reference.html

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='seismic')
